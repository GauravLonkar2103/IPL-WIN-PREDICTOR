# %%
import numpy as np
import pandas as pd

# %%
deliveries=pd.read_csv("match_data.csv",low_memory=False)
match=pd.read_csv("match_info_data.csv")

# %%
deliveries.head()
# Out:
#    match_id season  start_date                             venue  innings  \
# 0   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 1   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 2   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 3   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 4   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
#
#    ball    batting_team         bowling_team       striker   non_striker  ...  \
# 0   0.1  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 1   0.2  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 2   0.3  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 3   0.4  Gujarat Titans  Chennai Super Kings  Shubman Gill       WP Saha  ...
# 4   0.5  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
#
#   wides  noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 0   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 1   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 2   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 3   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 4   NaN      NaN   NaN      NaN      NaN          NaN               NaN
#
#    other_wicket_type other_player_dismissed cricsheet_id
# 0                NaN                    NaN      1370353
# 1                NaN                    NaN      1370353
# 2                NaN                    NaN      1370353
# 3                NaN                    NaN      1370353
# 4                NaN                    NaN      1370353
#
# [5 rows x 23 columns]

# %%
match.head()
# Out:
#         id season       city        date                team1  \
# 0  1370353   2023  Ahmedabad  2023/05/29       Gujarat Titans
# 1  1370352   2023  Ahmedabad  2023/05/26       Gujarat Titans
# 2  1370351   2023    Chennai  2023/05/24       Mumbai Indians
# 3  1370350   2023    Chennai  2023/05/23  Chennai Super Kings
# 4  1359543   2023     Mumbai  2023/05/21  Sunrisers Hyderabad
#
#                   team2          toss_winner toss_decision  result  \
# 0   Chennai Super Kings  Chennai Super Kings         field     D/L
# 1        Mumbai Indians       Mumbai Indians         field  normal
# 2  Lucknow Super Giants       Mumbai Indians           bat  normal
# 3        Gujarat Titans       Gujarat Titans         field  normal
# 4        Mumbai Indians       Mumbai Indians         field  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 0           1  Chennai Super Kings            0               5
# 1           0       Gujarat Titans           62               0
# 2           0       Mumbai Indians           81               0
# 3           0  Chennai Super Kings           15               0
# 4           0       Mumbai Indians            0               8
#
#   player_of_match                                     venue  \
# 0       DP Conway          Narendra Modi Stadium, Ahmedabad
# 1    Shubman Gill          Narendra Modi Stadium, Ahmedabad
# 2   Akash Madhwal  MA Chidambaram Stadium, Chepauk, Chennai
# 3      RD Gaikwad  MA Chidambaram Stadium, Chepauk, Chennai
# 4         C Green                  Wankhede Stadium, Mumbai
#
#                  umpire1      umpire2                umpire3
# 0            Nitin Menon    RJ Tucker  KN Ananthapadmanabhan
# 1            Nitin Menon    RJ Tucker          J Madanagopal
# 2           BNJ Oxenford    VK Sharma            CB Gaffaney
# 3           AK Chaudhary  CB Gaffaney           BNJ Oxenford
# 4  KN Ananthapadmanabhan    RJ Tucker               R Pandit

# %%
match.shape
deliveries.shape
# Out:
# (243817, 23)

# %%
match.shape
# Out:
# (1024, 18)

# %%
deliveries_df=pd.DataFrame(deliveries)

# %%
deliveries_df.head()
# Out:
#    match_id season  start_date                             venue  innings  \
# 0   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 1   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 2   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 3   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 4   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
#
#    ball    batting_team         bowling_team       striker   non_striker  ...  \
# 0   0.1  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 1   0.2  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 2   0.3  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 3   0.4  Gujarat Titans  Chennai Super Kings  Shubman Gill       WP Saha  ...
# 4   0.5  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
#
#   wides  noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 0   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 1   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 2   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 3   NaN      NaN   NaN      NaN      NaN          NaN               NaN
# 4   NaN      NaN   NaN      NaN      NaN          NaN               NaN
#
#    other_wicket_type other_player_dismissed cricsheet_id
# 0                NaN                    NaN      1370353
# 1                NaN                    NaN      1370353
# 2                NaN                    NaN      1370353
# 3                NaN                    NaN      1370353
# 4                NaN                    NaN      1370353
#
# [5 rows x 23 columns]

# %%
deliveries_df["tot_runs"]=deliveries_df["runs_off_bat"]+deliveries_df["extras"]

# %%
deliveries_df.head()
# Out:
#    match_id season  start_date                             venue  innings  \
# 0   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 1   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 2   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 3   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
# 4   1370353   2023  2023-05-29  Narendra Modi Stadium, Ahmedabad        1
#
#    ball    batting_team         bowling_team       striker   non_striker  ...  \
# 0   0.1  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 1   0.2  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 2   0.3  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
# 3   0.4  Gujarat Titans  Chennai Super Kings  Shubman Gill       WP Saha  ...
# 4   0.5  Gujarat Titans  Chennai Super Kings       WP Saha  Shubman Gill  ...
#
#   noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 0     NaN   NaN      NaN      NaN          NaN               NaN
# 1     NaN   NaN      NaN      NaN          NaN               NaN
# 2     NaN   NaN      NaN      NaN          NaN               NaN
# 3     NaN   NaN      NaN      NaN          NaN               NaN
# 4     NaN   NaN      NaN      NaN          NaN               NaN
#
#    other_wicket_type  other_player_dismissed cricsheet_id tot_runs
# 0                NaN                     NaN      1370353        0
# 1                NaN                     NaN      1370353        0
# 2                NaN                     NaN      1370353        1
# 3                NaN                     NaN      1370353        1
# 4                NaN                     NaN      1370353        1
#
# [5 rows x 24 columns]

# %%
match_df=pd.DataFrame(match)

# %%
total_score_df=deliveries_df.groupby(["match_id","innings"]).sum()["tot_runs"].reset_index()

# %%
total_score_df.tail()
# Out:
#       match_id  innings  tot_runs
# 2070   1370351        2       101
# 2071   1370352        1       233
# 2072   1370352        2       171
# 2073   1370353        1       214
# 2074   1370353        2       171

# %%
total_score_df=total_score_df[total_score_df["innings"]==1]

# %%
total_score_df
# Out:
#       match_id  innings  tot_runs
# 0       335982        1       222
# 2       335983        1       240
# 4       335984        1       129
# 6       335985        1       165
# 8       335986        1       110
# ...        ...      ...       ...
# 2065   1359544        1       197
# 2067   1370350        1       172
# 2069   1370351        1       182
# 2071   1370352        1       233
# 2073   1370353        1       214
#
# [1024 rows x 3 columns]

# %%
match_df=match_df.merge(total_score_df[["match_id","tot_runs"]],left_on="id",right_on="match_id")

# %%
match_df["team1"].unique()
# Out:
# array(['Gujarat Titans', 'Mumbai Indians', 'Chennai Super Kings',
#        'Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Lucknow Super Giants', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
teams=['Gujarat Titans', 'Mumbai Indians', 'Chennai Super Kings',
       'Sunrisers Hyderabad', 'Royal Challengers Bangalore',
       'Lucknow Super Giants', 'Delhi Capitals',
       'Kolkata Knight Riders', 'Rajasthan Royals', 'Kings XI Punjab',]

# %%
match_df["team1"]=match_df["team1"].str.replace("Delhi Daredevils","Delhi Capitals")
match_df["team2"]=match_df["team2"].str.replace("Delhi Daredevils","Delhi Capitals")

match_df["team2"]=match_df["team2"].str.replace("Deccan Chargers","Sunrisers Hyderabad")
match_df["team1"]=match_df["team1"].str.replace("Deccan Chargers","Sunrisers Hyderabad")

match_df["team1"]=match_df["team1"].str.replace("Punjab Kings","Kings XI Punjab")
match_df["team2"]=match_df["team2"].str.replace("Punjab Kings","Kings XI Punjab")

# %%
match_df=match_df[match_df["team1"].isin(teams)]
match_df=match_df[match_df["team2"].isin(teams)]

# %%
match_df
# Out:
#            id   season        city        date                        team1  \
# 0     1370353     2023   Ahmedabad  2023/05/29               Gujarat Titans
# 1     1370352     2023   Ahmedabad  2023/05/26               Gujarat Titans
# 2     1370351     2023     Chennai  2023/05/24               Mumbai Indians
# 3     1370350     2023     Chennai  2023/05/23          Chennai Super Kings
# 4     1359543     2023      Mumbai  2023/05/21          Sunrisers Hyderabad
# ...       ...      ...         ...         ...                          ...
# 1019   335986  2007/08     Kolkata  2008/04/20        Kolkata Knight Riders
# 1020   335985  2007/08      Mumbai  2008/04/20               Mumbai Indians
# 1021   335984  2007/08       Delhi  2008/04/19               Delhi Capitals
# 1022   335983  2007/08  Chandigarh  2008/04/19              Kings XI Punjab
# 1023   335982  2007/08   Bangalore  2008/04/18  Royal Challengers Bangalore
#
#                             team2                  toss_winner toss_decision  \
# 0             Chennai Super Kings          Chennai Super Kings         field
# 1                  Mumbai Indians               Mumbai Indians         field
# 2            Lucknow Super Giants               Mumbai Indians           bat
# 3                  Gujarat Titans               Gujarat Titans         field
# 4                  Mumbai Indians               Mumbai Indians         field
# ...                           ...                          ...           ...
# 1019          Sunrisers Hyderabad              Deccan Chargers           bat
# 1020  Royal Challengers Bangalore               Mumbai Indians           bat
# 1021             Rajasthan Royals             Rajasthan Royals           bat
# 1022          Chennai Super Kings          Chennai Super Kings           bat
# 1023        Kolkata Knight Riders  Royal Challengers Bangalore         field
#
#       result  dl_applied                       winner  win_by_runs  \
# 0        D/L           1          Chennai Super Kings            0
# 1     normal           0               Gujarat Titans           62
# 2     normal           0               Mumbai Indians           81
# 3     normal           0          Chennai Super Kings           15
# 4     normal           0               Mumbai Indians            0
# ...      ...         ...                          ...          ...
# 1019  normal           0        Kolkata Knight Riders            0
# 1020  normal           0  Royal Challengers Bangalore            0
# 1021  normal           0             Delhi Daredevils            0
# 1022  normal           0          Chennai Super Kings           33
# 1023  normal           0        Kolkata Knight Riders          140
#
#       win_by_wickets player_of_match  \
# 0                  5       DP Conway
# 1                  0    Shubman Gill
# 2                  0   Akash Madhwal
# 3                  0      RD Gaikwad
# 4                  8         C Green
# ...              ...             ...
# 1019               5       DJ Hussey
# 1020               5      MV Boucher
# 1021               9     MF Maharoof
# 1022               0      MEK Hussey
# 1023               0     BB McCullum
#
#                                            venue                umpire1  \
# 0               Narendra Modi Stadium, Ahmedabad            Nitin Menon
# 1               Narendra Modi Stadium, Ahmedabad            Nitin Menon
# 2       MA Chidambaram Stadium, Chepauk, Chennai           BNJ Oxenford
# 3       MA Chidambaram Stadium, Chepauk, Chennai           AK Chaudhary
# 4                       Wankhede Stadium, Mumbai  KN Ananthapadmanabhan
# ...                                          ...                    ...
# 1019                                Eden Gardens              BF Bowden
# 1020                            Wankhede Stadium               SJ Davis
# 1021                            Feroz Shah Kotla              Aleem Dar
# 1022  Punjab Cricket Association Stadium, Mohali              MR Benson
# 1023                       M Chinnaswamy Stadium              Asad Rauf
#
#              umpire2                umpire3  match_id  tot_runs
# 0          RJ Tucker  KN Ananthapadmanabhan   1370353       214
# 1          RJ Tucker          J Madanagopal   1370352       233
# 2          VK Sharma            CB Gaffaney   1370351       182
# 3        CB Gaffaney           BNJ Oxenford   1370350       172
# 4          RJ Tucker               R Pandit   1359543       200
# ...              ...                    ...       ...       ...
# 1019     K Hariharan              Asad Rauf    335986       110
# 1020       DJ Harper         AV Jayaprakash    335985       165
# 1021  GA Pratapkumar              IL Howell    335984       129
# 1022      SL Shastri              RB Tiffin    335983       240
# 1023     RE Koertzen              AM Saheba    335982       222
#
# [909 rows x 20 columns]

# %%
match_df=match_df[match_df["dl_applied"]==0]

# %%
match_df
# Out:
#            id   season        city        date                        team1  \
# 1     1370352     2023   Ahmedabad  2023/05/26               Gujarat Titans
# 2     1370351     2023     Chennai  2023/05/24               Mumbai Indians
# 3     1370350     2023     Chennai  2023/05/23          Chennai Super Kings
# 4     1359543     2023      Mumbai  2023/05/21          Sunrisers Hyderabad
# 5     1359544     2023   Bengaluru  2023/05/21  Royal Challengers Bangalore
# ...       ...      ...         ...         ...                          ...
# 1019   335986  2007/08     Kolkata  2008/04/20        Kolkata Knight Riders
# 1020   335985  2007/08      Mumbai  2008/04/20               Mumbai Indians
# 1021   335984  2007/08       Delhi  2008/04/19               Delhi Capitals
# 1022   335983  2007/08  Chandigarh  2008/04/19              Kings XI Punjab
# 1023   335982  2007/08   Bangalore  2008/04/18  Royal Challengers Bangalore
#
#                             team2                  toss_winner toss_decision  \
# 1                  Mumbai Indians               Mumbai Indians         field
# 2            Lucknow Super Giants               Mumbai Indians           bat
# 3                  Gujarat Titans               Gujarat Titans         field
# 4                  Mumbai Indians               Mumbai Indians         field
# 5                  Gujarat Titans               Gujarat Titans         field
# ...                           ...                          ...           ...
# 1019          Sunrisers Hyderabad              Deccan Chargers           bat
# 1020  Royal Challengers Bangalore               Mumbai Indians           bat
# 1021             Rajasthan Royals             Rajasthan Royals           bat
# 1022          Chennai Super Kings          Chennai Super Kings           bat
# 1023        Kolkata Knight Riders  Royal Challengers Bangalore         field
#
#       result  dl_applied                       winner  win_by_runs  \
# 1     normal           0               Gujarat Titans           62
# 2     normal           0               Mumbai Indians           81
# 3     normal           0          Chennai Super Kings           15
# 4     normal           0               Mumbai Indians            0
# 5     normal           0               Gujarat Titans            0
# ...      ...         ...                          ...          ...
# 1019  normal           0        Kolkata Knight Riders            0
# 1020  normal           0  Royal Challengers Bangalore            0
# 1021  normal           0             Delhi Daredevils            0
# 1022  normal           0          Chennai Super Kings           33
# 1023  normal           0        Kolkata Knight Riders          140
#
#       win_by_wickets player_of_match  \
# 1                  0    Shubman Gill
# 2                  0   Akash Madhwal
# 3                  0      RD Gaikwad
# 4                  8         C Green
# 5                  6    Shubman Gill
# ...              ...             ...
# 1019               5       DJ Hussey
# 1020               5      MV Boucher
# 1021               9     MF Maharoof
# 1022               0      MEK Hussey
# 1023               0     BB McCullum
#
#                                            venue                umpire1  \
# 1               Narendra Modi Stadium, Ahmedabad            Nitin Menon
# 2       MA Chidambaram Stadium, Chepauk, Chennai           BNJ Oxenford
# 3       MA Chidambaram Stadium, Chepauk, Chennai           AK Chaudhary
# 4                       Wankhede Stadium, Mumbai  KN Ananthapadmanabhan
# 5               M Chinnaswamy Stadium, Bengaluru            Nitin Menon
# ...                                          ...                    ...
# 1019                                Eden Gardens              BF Bowden
# 1020                            Wankhede Stadium               SJ Davis
# 1021                            Feroz Shah Kotla              Aleem Dar
# 1022  Punjab Cricket Association Stadium, Mohali              MR Benson
# 1023                       M Chinnaswamy Stadium              Asad Rauf
#
#              umpire2         umpire3  match_id  tot_runs
# 1          RJ Tucker   J Madanagopal   1370352       233
# 2          VK Sharma     CB Gaffaney   1370351       182
# 3        CB Gaffaney    BNJ Oxenford   1370350       172
# 4          RJ Tucker        R Pandit   1359543       200
# 5          VK Sharma    Tapan Sharma   1359544       197
# ...              ...             ...       ...       ...
# 1019     K Hariharan       Asad Rauf    335986       110
# 1020       DJ Harper  AV Jayaprakash    335985       165
# 1021  GA Pratapkumar       IL Howell    335984       129
# 1022      SL Shastri       RB Tiffin    335983       240
# 1023     RE Koertzen       AM Saheba    335982       222
#
# [892 rows x 20 columns]

# %%
match_df=match_df[["match_id","city","winner","tot_runs"]]

# %%
match_df
# Out:
#       match_id        city                       winner  tot_runs
# 1      1370352   Ahmedabad               Gujarat Titans       233
# 2      1370351     Chennai               Mumbai Indians       182
# 3      1370350     Chennai          Chennai Super Kings       172
# 4      1359543      Mumbai               Mumbai Indians       200
# 5      1359544   Bengaluru               Gujarat Titans       197
# ...        ...         ...                          ...       ...
# 1019    335986     Kolkata        Kolkata Knight Riders       110
# 1020    335985      Mumbai  Royal Challengers Bangalore       165
# 1021    335984       Delhi             Delhi Daredevils       129
# 1022    335983  Chandigarh          Chennai Super Kings       240
# 1023    335982   Bangalore        Kolkata Knight Riders       222
#
# [892 rows x 4 columns]

# %%
delivery_df=match_df.merge(deliveries_df,on="match_id")

# %%
delivery_df=delivery_df[delivery_df["innings"]==2]

# %%
delivery_df.shape
# Out:
# (103511, 27)

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... noballs byes legbyes penalty  \
# 127                  Mumbai Indians  ...     NaN  NaN     NaN     NaN
# 128                  Mumbai Indians  ...     NaN  NaN     NaN     NaN
# 129                  Mumbai Indians  ...     NaN  NaN     NaN     NaN
# 130                  Mumbai Indians  ...     NaN  NaN     NaN     NaN
# 131                  Mumbai Indians  ...     NaN  NaN     NaN     NaN
# ...                             ...  ...     ...  ...     ...     ...
# 213874  Royal Challengers Bangalore  ...     NaN  NaN     1.0     NaN
# 213875  Royal Challengers Bangalore  ...     NaN  NaN     NaN     NaN
# 213876  Royal Challengers Bangalore  ...     NaN  NaN     NaN     NaN
# 213877  Royal Challengers Bangalore  ...     NaN  NaN     NaN     NaN
# 213878  Royal Challengers Bangalore  ...     NaN  NaN     NaN     NaN
#
#         wicket_type  player_dismissed  other_wicket_type  \
# 127             NaN               NaN                NaN
# 128             NaN               NaN                NaN
# 129             NaN               NaN                NaN
# 130             NaN               NaN                NaN
# 131          caught         N Wadhera                NaN
# ...             ...               ...                ...
# 213874          NaN               NaN                NaN
# 213875          NaN               NaN                NaN
# 213876          NaN               NaN                NaN
# 213877          NaN               NaN                NaN
# 213878       caught          SB Joshi                NaN
#
#         other_player_dismissed  cricsheet_id  tot_runs_y
# 127                        NaN       1370352           0
# 128                        NaN       1370352           1
# 129                        NaN       1370352           0
# 130                        NaN       1370352           4
# 131                        NaN       1370352           0
# ...                        ...           ...         ...
# 213874                     NaN        335982           1
# 213875                     NaN        335982           1
# 213876                     NaN        335982           0
# 213877                     NaN        335982           1
# 213878                     NaN        335982           0
#
# [103511 rows x 27 columns]

# %%
delivery_df["current_score"]=delivery_df.groupby(["match_id"])["tot_runs_y"].cumsum()

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... byes legbyes penalty wicket_type  \
# 127                  Mumbai Indians  ...  NaN     NaN     NaN         NaN
# 128                  Mumbai Indians  ...  NaN     NaN     NaN         NaN
# 129                  Mumbai Indians  ...  NaN     NaN     NaN         NaN
# 130                  Mumbai Indians  ...  NaN     NaN     NaN         NaN
# 131                  Mumbai Indians  ...  NaN     NaN     NaN      caught
# ...                             ...  ...  ...     ...     ...         ...
# 213874  Royal Challengers Bangalore  ...  NaN     1.0     NaN         NaN
# 213875  Royal Challengers Bangalore  ...  NaN     NaN     NaN         NaN
# 213876  Royal Challengers Bangalore  ...  NaN     NaN     NaN         NaN
# 213877  Royal Challengers Bangalore  ...  NaN     NaN     NaN         NaN
# 213878  Royal Challengers Bangalore  ...  NaN     NaN     NaN      caught
#
#         player_dismissed  other_wicket_type  other_player_dismissed  \
# 127                  NaN                NaN                     NaN
# 128                  NaN                NaN                     NaN
# 129                  NaN                NaN                     NaN
# 130                  NaN                NaN                     NaN
# 131            N Wadhera                NaN                     NaN
# ...                  ...                ...                     ...
# 213874               NaN                NaN                     NaN
# 213875               NaN                NaN                     NaN
# 213876               NaN                NaN                     NaN
# 213877               NaN                NaN                     NaN
# 213878          SB Joshi                NaN                     NaN
#
#         cricsheet_id  tot_runs_y  current_score
# 127          1370352           0              0
# 128          1370352           1              1
# 129          1370352           0              1
# 130          1370352           4              5
# 131          1370352           0              5
# ...              ...         ...            ...
# 213874        335982           1             80
# 213875        335982           1             81
# 213876        335982           0             81
# 213877        335982           1             82
# 213878        335982           0             82
#
# [103511 rows x 28 columns]

# %%
delivery_df["runs_left"]=delivery_df["tot_runs_x"]-delivery_df["current_score"]+1

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... legbyes penalty wicket_type  \
# 127                  Mumbai Indians  ...     NaN     NaN         NaN
# 128                  Mumbai Indians  ...     NaN     NaN         NaN
# 129                  Mumbai Indians  ...     NaN     NaN         NaN
# 130                  Mumbai Indians  ...     NaN     NaN         NaN
# 131                  Mumbai Indians  ...     NaN     NaN      caught
# ...                             ...  ...     ...     ...         ...
# 213874  Royal Challengers Bangalore  ...     1.0     NaN         NaN
# 213875  Royal Challengers Bangalore  ...     NaN     NaN         NaN
# 213876  Royal Challengers Bangalore  ...     NaN     NaN         NaN
# 213877  Royal Challengers Bangalore  ...     NaN     NaN         NaN
# 213878  Royal Challengers Bangalore  ...     NaN     NaN      caught
#
#        player_dismissed  other_wicket_type  other_player_dismissed  \
# 127                 NaN                NaN                     NaN
# 128                 NaN                NaN                     NaN
# 129                 NaN                NaN                     NaN
# 130                 NaN                NaN                     NaN
# 131           N Wadhera                NaN                     NaN
# ...                 ...                ...                     ...
# 213874              NaN                NaN                     NaN
# 213875              NaN                NaN                     NaN
# 213876              NaN                NaN                     NaN
# 213877              NaN                NaN                     NaN
# 213878         SB Joshi                NaN                     NaN
#
#         cricsheet_id  tot_runs_y  current_score  runs_left
# 127          1370352           0              0        234
# 128          1370352           1              1        233
# 129          1370352           0              1        233
# 130          1370352           4              5        229
# 131          1370352           0              5        229
# ...              ...         ...            ...        ...
# 213874        335982           1             80        143
# 213875        335982           1             81        142
# 213876        335982           0             81        142
# 213877        335982           1             82        141
# 213878        335982           0             82        141
#
# [103511 rows x 29 columns]

# %%
delivery_df["balls_left"]=(120-(delivery_df["ball"].astype(int)*6+(delivery_df["ball"]-delivery_df["ball"].astype(int))*10)).astype(int)

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... wicket_type player_dismissed  \
# 127                  Mumbai Indians  ...         NaN                0
# 128                  Mumbai Indians  ...         NaN                0
# 129                  Mumbai Indians  ...         NaN                0
# 130                  Mumbai Indians  ...         NaN                0
# 131                  Mumbai Indians  ...      caught                1
# ...                             ...  ...         ...              ...
# 213874  Royal Challengers Bangalore  ...         NaN                0
# 213875  Royal Challengers Bangalore  ...         NaN                0
# 213876  Royal Challengers Bangalore  ...         NaN                0
# 213877  Royal Challengers Bangalore  ...         NaN                0
# 213878  Royal Challengers Bangalore  ...      caught                1
#
#        other_wicket_type other_player_dismissed  cricsheet_id  tot_runs_y  \
# 127                  NaN                    NaN       1370352           0
# 128                  NaN                    NaN       1370352           1
# 129                  NaN                    NaN       1370352           0
# 130                  NaN                    NaN       1370352           4
# 131                  NaN                    NaN       1370352           0
# ...                  ...                    ...           ...         ...
# 213874               NaN                    NaN        335982           1
# 213875               NaN                    NaN        335982           1
# 213876               NaN                    NaN        335982           0
# 213877               NaN                    NaN        335982           1
# 213878               NaN                    NaN        335982           0
#
#         current_score  runs_left  wickets  balls_left
# 127                 0        234       10         119
# 128                 1        233       10         118
# 129                 1        233       10         117
# 130                 5        229       10         116
# 131                 5        229        9         115
# ...               ...        ...      ...         ...
# 213874             80        143        1          31
# 213875             81        142        1          30
# 213876             81        142        1          29
# 213877             82        141        1          29
# 213878             82        141        0          28
#
# [103511 rows x 31 columns]

# %%
delivery_df["player_dismissed"]=delivery_df["player_dismissed"].fillna("0")

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... wicket_type player_dismissed  \
# 127                  Mumbai Indians  ...         NaN                0
# 128                  Mumbai Indians  ...         NaN                0
# 129                  Mumbai Indians  ...         NaN                0
# 130                  Mumbai Indians  ...         NaN                0
# 131                  Mumbai Indians  ...      caught                1
# ...                             ...  ...         ...              ...
# 213874  Royal Challengers Bangalore  ...         NaN                0
# 213875  Royal Challengers Bangalore  ...         NaN                0
# 213876  Royal Challengers Bangalore  ...         NaN                0
# 213877  Royal Challengers Bangalore  ...         NaN                0
# 213878  Royal Challengers Bangalore  ...      caught                1
#
#        other_wicket_type other_player_dismissed  cricsheet_id  tot_runs_y  \
# 127                  NaN                    NaN       1370352           0
# 128                  NaN                    NaN       1370352           1
# 129                  NaN                    NaN       1370352           0
# 130                  NaN                    NaN       1370352           4
# 131                  NaN                    NaN       1370352           0
# ...                  ...                    ...           ...         ...
# 213874               NaN                    NaN        335982           1
# 213875               NaN                    NaN        335982           1
# 213876               NaN                    NaN        335982           0
# 213877               NaN                    NaN        335982           1
# 213878               NaN                    NaN        335982           0
#
#         current_score  runs_left  wickets  balls_left
# 127                 0        234       10         119
# 128                 1        233       10         118
# 129                 1        233       10         117
# 130                 5        229       10         116
# 131                 5        229        9         115
# ...               ...        ...      ...         ...
# 213874             80        143        1          31
# 213875             81        142        1          30
# 213876             81        142        1          29
# 213877             82        141        1          29
# 213878             82        141        0          28
#
# [103511 rows x 31 columns]

# %%
delivery_df["player_dismissed"]=delivery_df["player_dismissed"].apply(lambda x:x if x=="0" else "1")

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... wicket_type player_dismissed  \
# 127                  Mumbai Indians  ...         NaN                1
# 128                  Mumbai Indians  ...         NaN                1
# 129                  Mumbai Indians  ...         NaN                1
# 130                  Mumbai Indians  ...         NaN                1
# 131                  Mumbai Indians  ...      caught                1
# ...                             ...  ...         ...              ...
# 213874  Royal Challengers Bangalore  ...         NaN                1
# 213875  Royal Challengers Bangalore  ...         NaN                1
# 213876  Royal Challengers Bangalore  ...         NaN                1
# 213877  Royal Challengers Bangalore  ...         NaN                1
# 213878  Royal Challengers Bangalore  ...      caught                1
#
#        other_wicket_type other_player_dismissed  cricsheet_id  tot_runs_y  \
# 127                  NaN                    NaN       1370352           0
# 128                  NaN                    NaN       1370352           1
# 129                  NaN                    NaN       1370352           0
# 130                  NaN                    NaN       1370352           4
# 131                  NaN                    NaN       1370352           0
# ...                  ...                    ...           ...         ...
# 213874               NaN                    NaN        335982           1
# 213875               NaN                    NaN        335982           1
# 213876               NaN                    NaN        335982           0
# 213877               NaN                    NaN        335982           1
# 213878               NaN                    NaN        335982           0
#
#         current_score  runs_left  wickets  balls_left
# 127                 0        234       10         119
# 128                 1        233       10         118
# 129                 1        233       10         117
# 130                 5        229       10         116
# 131                 5        229        9         115
# ...               ...        ...      ...         ...
# 213874             80        143        1          31
# 213875             81        142        1          30
# 213876             81        142        1          29
# 213877             82        141        1          29
# 213878             82        141        0          28
#
# [103511 rows x 31 columns]

# %%
delivery_df["player_dismissed"]=delivery_df["player_dismissed"].astype(int)

# %%
wickets=delivery_df.groupby("match_id")["player_dismissed"].cumsum().values

# %%
delivery_df["wickets"]=10-wickets

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... wicket_type player_dismissed  \
# 127                  Mumbai Indians  ...         NaN                1
# 128                  Mumbai Indians  ...         NaN                1
# 129                  Mumbai Indians  ...         NaN                1
# 130                  Mumbai Indians  ...         NaN                1
# 131                  Mumbai Indians  ...      caught                1
# ...                             ...  ...         ...              ...
# 213874  Royal Challengers Bangalore  ...         NaN                1
# 213875  Royal Challengers Bangalore  ...         NaN                1
# 213876  Royal Challengers Bangalore  ...         NaN                1
# 213877  Royal Challengers Bangalore  ...         NaN                1
# 213878  Royal Challengers Bangalore  ...      caught                1
#
#        other_wicket_type other_player_dismissed  cricsheet_id  tot_runs_y  \
# 127                  NaN                    NaN       1370352           0
# 128                  NaN                    NaN       1370352           1
# 129                  NaN                    NaN       1370352           0
# 130                  NaN                    NaN       1370352           4
# 131                  NaN                    NaN       1370352           0
# ...                  ...                    ...           ...         ...
# 213874               NaN                    NaN        335982           1
# 213875               NaN                    NaN        335982           1
# 213876               NaN                    NaN        335982           0
# 213877               NaN                    NaN        335982           1
# 213878               NaN                    NaN        335982           0
#
#         current_score  runs_left  wickets  balls_left
# 127                 0        234        9         119
# 128                 1        233        8         118
# 129                 1        233        7         117
# 130                 5        229        6         116
# 131                 5        229        5         115
# ...               ...        ...      ...         ...
# 213874             80        143      -87          31
# 213875             81        142      -88          30
# 213876             81        142      -89          29
# 213877             82        141      -90          29
# 213878             82        141      -91          28
#
# [103511 rows x 31 columns]

# %%
delivery_df["crr"]=(delivery_df["current_score"]*6/(120-delivery_df["balls_left"]))

# %%
delivery_df["rrr"]=(delivery_df["runs_left"]*6/delivery_df["balls_left"])

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... other_wicket_type  \
# 127                  Mumbai Indians  ...               NaN
# 128                  Mumbai Indians  ...               NaN
# 129                  Mumbai Indians  ...               NaN
# 130                  Mumbai Indians  ...               NaN
# 131                  Mumbai Indians  ...               NaN
# ...                             ...  ...               ...
# 213874  Royal Challengers Bangalore  ...               NaN
# 213875  Royal Challengers Bangalore  ...               NaN
# 213876  Royal Challengers Bangalore  ...               NaN
# 213877  Royal Challengers Bangalore  ...               NaN
# 213878  Royal Challengers Bangalore  ...               NaN
#
#        other_player_dismissed cricsheet_id tot_runs_y  current_score  \
# 127                       NaN      1370352          0              0
# 128                       NaN      1370352          1              1
# 129                       NaN      1370352          0              1
# 130                       NaN      1370352          4              5
# 131                       NaN      1370352          0              5
# ...                       ...          ...        ...            ...
# 213874                    NaN       335982          1             80
# 213875                    NaN       335982          1             81
# 213876                    NaN       335982          0             81
# 213877                    NaN       335982          1             82
# 213878                    NaN       335982          0             82
#
#         runs_left  wickets  balls_left       crr        rrr
# 127           234        9         119  0.000000  11.798319
# 128           233        8         118  3.000000  11.847458
# 129           233        7         117  2.000000  11.948718
# 130           229        6         116  7.500000  11.844828
# 131           229        5         115  6.000000  11.947826
# ...           ...      ...         ...       ...        ...
# 213874        143      -87          31  5.393258  27.677419
# 213875        142      -88          30  5.400000  28.400000
# 213876        142      -89          29  5.340659  29.379310
# 213877        141      -90          29  5.406593  29.172414
# 213878        141      -91          28  5.347826  30.214286
#
# [103511 rows x 33 columns]

# %%
def result(row):
    return 1 if row["batting_team"]==row["winner"] else 0

# %%
delivery_df["result"]=delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         match_id       city                 winner  tot_runs_x   season  \
# 127      1370352  Ahmedabad         Gujarat Titans         233     2023
# 128      1370352  Ahmedabad         Gujarat Titans         233     2023
# 129      1370352  Ahmedabad         Gujarat Titans         233     2023
# 130      1370352  Ahmedabad         Gujarat Titans         233     2023
# 131      1370352  Ahmedabad         Gujarat Titans         233     2023
# ...          ...        ...                    ...         ...      ...
# 213874    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213875    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213876    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213877    335982  Bangalore  Kolkata Knight Riders         222  2007/08
# 213878    335982  Bangalore  Kolkata Knight Riders         222  2007/08
#
#         start_date                             venue  innings  ball  \
# 127     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.1
# 128     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.2
# 129     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.3
# 130     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.4
# 131     2023-05-26  Narendra Modi Stadium, Ahmedabad        2   0.5
# ...            ...                               ...      ...   ...
# 213874  2008-04-18             M Chinnaswamy Stadium        2  14.5
# 213875  2008-04-18             M Chinnaswamy Stadium        2  14.6
# 213876  2008-04-18             M Chinnaswamy Stadium        2  14.7
# 213877  2008-04-18             M Chinnaswamy Stadium        2  15.1
# 213878  2008-04-18             M Chinnaswamy Stadium        2  15.2
#
#                        batting_team  ... other_player_dismissed cricsheet_id  \
# 127                  Mumbai Indians  ...                    NaN      1370352
# 128                  Mumbai Indians  ...                    NaN      1370352
# 129                  Mumbai Indians  ...                    NaN      1370352
# 130                  Mumbai Indians  ...                    NaN      1370352
# 131                  Mumbai Indians  ...                    NaN      1370352
# ...                             ...  ...                    ...          ...
# 213874  Royal Challengers Bangalore  ...                    NaN       335982
# 213875  Royal Challengers Bangalore  ...                    NaN       335982
# 213876  Royal Challengers Bangalore  ...                    NaN       335982
# 213877  Royal Challengers Bangalore  ...                    NaN       335982
# 213878  Royal Challengers Bangalore  ...                    NaN       335982
#
#        tot_runs_y current_score  runs_left  wickets  balls_left       crr  \
# 127             0             0        234        9         119  0.000000
# 128             1             1        233        8         118  3.000000
# 129             0             1        233        7         117  2.000000
# 130             4             5        229        6         116  7.500000
# 131             0             5        229        5         115  6.000000
# ...           ...           ...        ...      ...         ...       ...
# 213874          1            80        143      -87          31  5.393258
# 213875          1            81        142      -88          30  5.400000
# 213876          0            81        142      -89          29  5.340659
# 213877          1            82        141      -90          29  5.406593
# 213878          0            82        141      -91          28  5.347826
#
#               rrr  result
# 127     11.798319       0
# 128     11.847458       0
# 129     11.948718       0
# 130     11.844828       0
# 131     11.947826       0
# ...           ...     ...
# 213874  27.677419       0
# 213875  28.400000       0
# 213876  29.379310       0
# 213877  29.172414       0
# 213878  30.214286       0
#
# [103511 rows x 34 columns]

# %%
final_df=delivery_df[["batting_team","bowling_team","city","runs_left","balls_left","wickets","tot_runs_x","crr","rrr","result"]]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                        batting_team         bowling_team        city  \
# 175698             Delhi Daredevils  Chennai Super Kings     Chennai
# 69806              Rajasthan Royals       Mumbai Indians      Jaipur
# 54206           Sunrisers Hyderabad      Kings XI Punjab         NaN
# 129750               Mumbai Indians  Sunrisers Hyderabad         NaN
# 32089         Kolkata Knight Riders       Mumbai Indians        Pune
# ...                             ...                  ...         ...
# 112630              Kings XI Punjab       Mumbai Indians  Chandigarh
# 211896             Rajasthan Royals      Deccan Chargers   Hyderabad
# 153398  Royal Challengers Bangalore       Mumbai Indians      Mumbai
# 179060              Deccan Chargers     Rajasthan Royals      Nagpur
# 123684        Kolkata Knight Riders  Chennai Super Kings     Kolkata
#
#         runs_left  balls_left  wickets  tot_runs_x       crr        rrr  \
# 175698         37          36      -78         112  5.428571   6.166667
# 69806         107          86      -24         161  9.705882   7.465116
# 54206          87          92      -20         126  8.571429   5.673913
# 129750        130          71      -42         172  5.265306  10.985915
# 32089         148         101       -9         161  4.421053   8.792079
# ...           ...         ...      ...         ...       ...        ...
# 112630         67          35      -77         172  7.482353  11.485714
# 211896        196         101       -9         214  6.000000  11.643564
# 153398         90          64      -46         141  5.571429   8.437500
# 179060         40          27      -89         159  7.741935   8.888889
# 123684         66          58      -53         154  8.612903   6.827586
#
#         result
# 175698       1
# 69806        1
# 54206        0
# 129750       0
# 32089        1
# ...        ...
# 112630       0
# 211896       1
# 153398       1
# 179060       0
# 123684       1
#
# [103511 rows x 10 columns]

# %%
final_df.dropna(inplace=True)

# %%
final_df=final_df[final_df["balls_left"]!=0]

# %%
final_df.describe()
# Out:
#           runs_left    balls_left       wickets    tot_runs_x           crr  \
# count  97160.000000  97160.000000  97160.000000  97160.000000  97160.000000
# mean      93.909541     62.632328    -49.191396    166.657956      7.474876
# std       50.236440     33.390410     34.451723     29.392410      2.278886
# min       -5.000000     -2.000000   -126.000000     62.000000      0.000000
# 25%       54.000000     35.000000    -78.000000    148.000000      6.307692
# 50%       93.000000     62.000000    -49.000000    166.000000      7.525424
# 75%      131.000000     91.000000    -19.000000    187.000000      8.727273
# max      258.000000    119.000000      9.000000    257.000000     36.000000
#
#                 rrr        result
# count  97160.000000  97160.000000
# mean      10.752082      0.514872
# std       14.513239      0.499781
# min     -516.000000      0.000000
# 25%        7.320000      0.000000
# 50%        9.026549      1.000000
# 75%       11.169231      1.000000
# max      714.000000      1.000000

# %%
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team        city  \
# 104166              Kings XI Punjab               Mumbai Indians  Chandigarh
# 128126  Royal Challengers Bangalore               Mumbai Indians      Mumbai
# 170205             Delhi Daredevils              Deccan Chargers       Delhi
# 104886               Mumbai Indians  Royal Challengers Bangalore      Mumbai
# 127844        Kolkata Knight Riders             Delhi Daredevils       Delhi
# ...                             ...                          ...         ...
# 173938  Royal Challengers Bangalore               Mumbai Indians      Mumbai
# 37476   Royal Challengers Bangalore          Sunrisers Hyderabad   Abu Dhabi
# 31183   Royal Challengers Bangalore               Mumbai Indians        Pune
# 149342               Mumbai Indians          Chennai Super Kings   Bangalore
# 77317               Kings XI Punjab        Kolkata Knight Riders     Kolkata
#
#         runs_left  balls_left  wickets  tot_runs_x       crr        rrr
# 104166        160          94      -16         189  6.923077  10.212766
# 128126         45          19      -94         187  8.495050  14.210526
# 170205        116          74      -36         168  6.913043   9.405405
# 104886        164         109       -1         170  3.818182   9.027523
# 127844         71          60      -51         160  9.000000   7.100000
# ...           ...         ...      ...         ...       ...        ...
# 173938        153          95      -15         184  7.680000   9.663158
# 37476          50          35      -77         141  6.494118   8.571429
# 31183          63          46      -66         151  7.216216   8.217391
# 149342         76          29      -85         187  7.384615  15.724138
# 77317         207         108       -2         218  6.000000  11.500000
#
# [77728 rows x 9 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
],
remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7966241251543845

# %%
pipe.predict_proba(X_test)[8]
# Out:
# array([0.05467573, 0.94532427])

# %%
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
match
# Out:
#            id   season        city        date                        team1  \
# 0     1370353     2023   Ahmedabad  2023/05/29               Gujarat Titans
# 1     1370352     2023   Ahmedabad  2023/05/26               Gujarat Titans
# 2     1370351     2023     Chennai  2023/05/24               Mumbai Indians
# 3     1370350     2023     Chennai  2023/05/23          Chennai Super Kings
# 4     1359543     2023      Mumbai  2023/05/21          Sunrisers Hyderabad
# ...       ...      ...         ...         ...                          ...
# 1019   335986  2007/08     Kolkata  2008/04/20        Kolkata Knight Riders
# 1020   335985  2007/08      Mumbai  2008/04/20               Mumbai Indians
# 1021   335984  2007/08       Delhi  2008/04/19             Delhi Daredevils
# 1022   335983  2007/08  Chandigarh  2008/04/19              Kings XI Punjab
# 1023   335982  2007/08   Bangalore  2008/04/18  Royal Challengers Bangalore
#
#                             team2                  toss_winner toss_decision  \
# 0             Chennai Super Kings          Chennai Super Kings         field
# 1                  Mumbai Indians               Mumbai Indians         field
# 2            Lucknow Super Giants               Mumbai Indians           bat
# 3                  Gujarat Titans               Gujarat Titans         field
# 4                  Mumbai Indians               Mumbai Indians         field
# ...                           ...                          ...           ...
# 1019              Deccan Chargers              Deccan Chargers           bat
# 1020  Royal Challengers Bangalore               Mumbai Indians           bat
# 1021             Rajasthan Royals             Rajasthan Royals           bat
# 1022          Chennai Super Kings          Chennai Super Kings           bat
# 1023        Kolkata Knight Riders  Royal Challengers Bangalore         field
#
#       result  dl_applied                       winner  win_by_runs  \
# 0        D/L           1          Chennai Super Kings            0
# 1     normal           0               Gujarat Titans           62
# 2     normal           0               Mumbai Indians           81
# 3     normal           0          Chennai Super Kings           15
# 4     normal           0               Mumbai Indians            0
# ...      ...         ...                          ...          ...
# 1019  normal           0        Kolkata Knight Riders            0
# 1020  normal           0  Royal Challengers Bangalore            0
# 1021  normal           0             Delhi Daredevils            0
# 1022  normal           0          Chennai Super Kings           33
# 1023  normal           0        Kolkata Knight Riders          140
#
#       win_by_wickets player_of_match  \
# 0                  5       DP Conway
# 1                  0    Shubman Gill
# 2                  0   Akash Madhwal
# 3                  0      RD Gaikwad
# 4                  8         C Green
# ...              ...             ...
# 1019               5       DJ Hussey
# 1020               5      MV Boucher
# 1021               9     MF Maharoof
# 1022               0      MEK Hussey
# 1023               0     BB McCullum
#
#                                            venue                umpire1  \
# 0               Narendra Modi Stadium, Ahmedabad            Nitin Menon
# 1               Narendra Modi Stadium, Ahmedabad            Nitin Menon
# 2       MA Chidambaram Stadium, Chepauk, Chennai           BNJ Oxenford
# 3       MA Chidambaram Stadium, Chepauk, Chennai           AK Chaudhary
# 4                       Wankhede Stadium, Mumbai  KN Ananthapadmanabhan
# ...                                          ...                    ...
# 1019                                Eden Gardens              BF Bowden
# 1020                            Wankhede Stadium               SJ Davis
# 1021                            Feroz Shah Kotla              Aleem Dar
# 1022  Punjab Cricket Association Stadium, Mohali              MR Benson
# 1023                       M Chinnaswamy Stadium              Asad Rauf
#
#              umpire2                umpire3
# 0          RJ Tucker  KN Ananthapadmanabhan
# 1          RJ Tucker          J Madanagopal
# 2          VK Sharma            CB Gaffaney
# 3        CB Gaffaney           BNJ Oxenford
# 4          RJ Tucker               R Pandit
# ...              ...                    ...
# 1019     K Hariharan              Asad Rauf
# 1020       DJ Harper         AV Jayaprakash
# 1021  GA Pratapkumar              IL Howell
# 1022      SL Shastri              RB Tiffin
# 1023     RE Koertzen              AM Saheba
#
# [1024 rows x 18 columns]

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
   
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','tot_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['tot_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,1359543,pipe)
temp_df
# Out:
# Target- 200
#      end_of_over  runs_after_over  wickets_in_over  lose   win
# 850            1               -1                1  84.6  15.4
# 851            2                0                1  85.8  14.2
# 852            3                2                1  82.8  17.2
# 853            4                1                1  82.8  17.2
# 854            5                0                1  84.7  15.3
# ..           ...              ...              ...   ...   ...
# 958          109                4                1   1.8  98.2
# 959          110                1                1   1.8  98.2
# 960          111                1                1   1.8  98.2
# 961          112                0                1   2.0  98.0
# 962          113                1                1   2.1  97.9
#
# [113 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-200')

# %%
teams
# Out:
# ['Gujarat Titans',
#  'Mumbai Indians',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Royal Challengers Bangalore',
#  'Lucknow Super Giants',
#  'Delhi Capitals',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Kings XI Punjab']

# %%
delivery_df['city'].unique()
# Out:
# array(['Ahmedabad', 'Chennai', 'Mumbai', 'Bengaluru', 'Kolkata', 'Delhi',
#        'Dharamsala', 'Hyderabad', 'Lucknow', 'Jaipur', 'Chandigarh',
#        'Guwahati', 'Navi Mumbai', 'Pune', 'Dubai', 'Sharjah', 'Abu Dhabi',
#        nan, 'Visakhapatnam', 'Indore', 'Bangalore', 'Raipur', 'Ranchi',
#        'Cuttack', 'Nagpur', 'Johannesburg', 'Centurion', 'Durban',
#        'Bloemfontein', 'Port Elizabeth', 'Kimberley', 'East London',
#        'Cape Town'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
